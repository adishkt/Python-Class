# %%
tupl=(122,22,34)
print(tupl)
print(type(tupl))
# Out:
# (122, 22, 34)
# <class 'tuple'>

# %%
#swapping
a=10
b=20
print(f"Before swap : a={a}, b={b}")
a,b=b,a
print(f"After swap : a={a}, b={b}")
# Out:
# Before swap : a=10, b=20
# After swap : a=20, b=10

# %%
movie=("KGF","10:30 am","Screen 3","Elements mall PVR")
print(movie)
movie_name,timings,screen,location=movie
print(movie_name)
print(timings)
# Out:
# ('KGF', '10:30 am', 'Screen 3', 'Elements mall PVR')
# KGF
# 10:30 am

# %%
num=int(input("Enter a number: "))
reversed_num=0
while num>0:
    digit=num%10
    reversed_num=reversed_num*10+digit
    num=num//10
print(reversed_num)
# Out:
# 255433
