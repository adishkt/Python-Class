# %%
import requests

address = "Kalyan nagar"

places = requests.get("https://nominatim.openstreetmap.org/search", params={"q": f"restaurants in {address}", "format": "jsonv2", "limit": 6}, headers={"User-Agent": "tapngo-app"}, timeout=20).json()

# %%
places
# Out:
# [{'place_id': 252350902,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4447315290,
#   'lat': '13.0219932',
#   'lon': '77.6405659',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.00027296404524946037,
#   'addresstype': 'amenity',
#   'name': 'Mast Kalandar',
#   'display_name': 'Mast Kalandar, CMR Road, Kalyan Nagar, Kalyanagar, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India',
#   'boundingbox': ['13.0219432', '13.0220432', '77.6405159', '77.6406159']},
#  {'place_id': 252381294,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4447006252,
#   'lat': '13.0222385',
#   'lon': '77.6399929',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.00035729094587340013,
#   'addresstype': 'amenity',
#   'name': 'Cake House',
#   'display_name': 'Cake House, 5th A Main Road, HRBR Layout 2nd Block, Kacharakanahalli, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India',
#   'boundingbox': ['13.0221885', '13.0222885', '77.6399429', '77.6400429']},
#  {'place_id': 252390628,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 13013584298,
#   'lat': '13.0220219',
#   'lon': '77.6399329',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.0004212639315152187,
#   'addresstype': 'amenity',
#   'name': 'Venn',
#   'display_name': 'Venn, 5th A Main Road, HRBR Layout 2nd Block, Kacharakanahalli, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India',
#   'boundingbox': ['13.0219719', '13.0220719', '77.6398829', '77.6399829']},
#  {'place_id': 252508291,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4447291372,
#   'lat': '13.0221892',
#   'lon': '77.6397816',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.0005572367539862177,
#   'addresstype': 'amenity',
#   'name': "Chung's Chinese Corner",
#   'display_name': "Chung's Chinese Corner, 401, 5th Main Road, HRBR Layout 2nd Block, Kacharakanahalli, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India",
#   'boundingbox': ['13.0221392', '13.0222392', '77.6397316', '77.6398316']},
#  {'place_id': 252381326,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4447363016,
#   'lat': '13.0215823',
#   'lon': '77.6403247',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.0005594308715105757,
#   'addresstype': 'amenity',
#   'name': 'Barbeque Nation',
#   'display_name': 'Barbeque Nation, No. 30,, CMR Road, Kalyan Nagar, Kalyanagar, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India',
#   'boundingbox': ['13.0215323', '13.0216323', '77.6402747', '77.6403747']},
#  {'place_id': 252230122,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 4446975139,
#   'lat': '13.0222694',
#   'lon': '77.6397678',
#   'category': 'amenity',
#   'type': 'restaurant',
#   'place_rank': 30,
#   'importance': -0.0005831756510682478,
#   'addresstype': 'amenity',
#   'name': 'Faasos',
#   'display_name': 'Faasos, 406, 5th Main Road, HRBR Layout 2nd Block, Kacharakanahalli, Bengaluru North City Corporation, Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, 560043, India',
#   'boundingbox': ['13.0222194', '13.0223194', '77.6397178', '77.6398178']}]
