# %%
grocery={"Rice":80,"Wheat":45,"Milk":60,"Oil":180,"Rice":800}

# %%
grocery['Ragi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 grocery['Ragi']
#
# KeyError: 'Ragi'

# %%
grocery.get('Ragi',"Not Found")
# Out:
# 'Not Found'

# %%
grocery['Rice']
# Out:
# 800

# %%
grocery
# Out:
# {'Rice': 800, 'Wheat': 45, 'Milk': 60, 'Oil': 180}

# %%
'Rice' in grocery
# Out:
# True
