# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 6.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.8 MB 9.3 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.8 MB 9.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.8 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.5 MB 13.4 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.5 MB 12.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.5 MB 12.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.5 MB 11.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
pd.read_html("https://www.espn.in/football/club/_/id/349/afc-bournemouth")[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1304, in _find_and_load_unlocked(name, import_)
#
# ...

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 3.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/4.0 MB 2.7 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/4.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.5 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pd.read_html("https://www.espn.in/football/club/_/id/349/afc-bournemouth")[0]
# Out:
#                       Team  GP  W  D  L  GD  P
# 0          AFC Bournemouth   0  0  0  0   0  0
# 1                  Arsenal   0  0  0  0   0  0
# 2              Aston Villa   0  0  0  0   0  0
# 3                Brentford   0  0  0  0   0  0
# 4   Brighton & Hove Albion   0  0  0  0   0  0
# 5                  Chelsea   0  0  0  0   0  0
# 6            Coventry City   0  0  0  0   0  0
# 7           Crystal Palace   0  0  0  0   0  0
# 8                  Everton   0  0  0  0   0  0
# 9                   Fulham   0  0  0  0   0  0
# 10               Hull City   0  0  0  0   0  0
# 11            Ipswich Town   0  0  0  0   0  0
# 12            Leeds United   0  0  0  0   0  0
# 13               Liverpool   0  0  0  0   0  0
# 14         Manchester City   0  0  0  0   0  0
# 15       Manchester United   0  0  0  0   0  0
# 16        Newcastle United   0  0  0  0   0  0
# 17       Nottingham Forest   0  0  0  0   0  0
# 18              Sunderland   0  0  0  0   0  0
# ...
